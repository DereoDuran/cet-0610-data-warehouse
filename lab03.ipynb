# %%
import pandas as pd
from utils import MysqlConnector
conn = MysqlConnector()

# %%
pd.set_option('display.max_rows', None)

# %% [markdown]
# 1. Gráfico do volume de vendas por cliente – lista dos maiores clientes - Top 10

# %%
result = conn.fetch('''
SELECT
    c.customer_name,
    SUM(o.order_amount) AS total
FROM
    customer_dim c
INNER JOIN sales_order_fact o ON
    c.customer_sk = o.customer_sk
GROUP BY
    c.customer_name
ORDER BY
    total DESC
LIMIT 10
''')

# %%
df = pd.DataFrame(result, columns=['Nome do cliente', 'Total vendido'])
df.set_index('Nome do cliente', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#                   Total vendido
# Nome do cliente
# Iron Mount             143220.0
# Medium Retailers       129400.0
# Small Stores           115320.0
# Good Companies         106970.0
# Wonderful Shops         93000.0
# Ticanos Com             80000.0
# Big Customers           75400.0
# Mex Free                53400.0
# Good Products           46000.0
# Loyal Clients           43750.0

# %%
df.plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Nome do cliente'>

# %% [markdown]
# 2. Gráfico dos valores de pedidos, agrupados por produtos vendidos.

# %%
result = conn.fetch('''
SELECT
    p.product_name,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN product_dim p ON
    o.product_sk = p.product_sk
GROUP BY
    p.product_name
ORDER BY
    total DESC
''')

# %%
df = pd.DataFrame(result, columns=['Nome do produto', 'Total vendido'])
df.set_index('Nome do produto', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#                  Total vendido
# Nome do produto
# Pen Drive             294400.0
# Mouse                 189150.0
# Keyboard              149500.0
# Batery                131600.0
# Pocket Storage        105200.0
# LCD Panel             101600.0
# Ink Print              83500.0
# Microphone             48500.0
# External Cam           48340.0
# Backup Storage         35000.0
# Head Phone             34400.0
# WebCam                 32300.0
# Filter                  1230.0
# Hard Disk                640.0

# %%
df.plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Nome do produto'>

# %% [markdown]
# 3. Gráfico da soma dos valores de pedidos, verificando as dimensões de data e ordens.

# %%
result = conn.fetch('''
SELECT
    d.date,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
GROUP BY
    d.date
ORDER BY
    d.date ASC;
''')

# %%
df = pd.DataFrame(result, columns=['Data', 'Total vendido'])
df.set_index('Data', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#             Total vendido
# Data
# 2005-01-31         4000.0
# 2005-02-28         2000.0
# 2005-03-31         4000.0
# 2005-04-30         4000.0
# 2005-05-31        12000.0
# 2005-06-30        13000.0
# 2005-07-31        16000.0
# 2005-08-31         8000.0
# 2005-09-30        30000.0
# 2005-10-31        49200.0
# 2005-11-30        20400.0
# 2005-12-31         2500.0
# 2006-01-31        21340.0
# 2006-02-28         7600.0
# 2006-03-31         7000.0
# 2006-04-30        18000.0
# 2006-05-31        14000.0
# 2006-06-30        16500.0
# 2006-07-31        30500.0
# 2006-08-31        16000.0
# 2006-09-30        16500.0
# 2006-10-31        17200.0
# 2006-11-30        22440.0
# 2006-12-31        24600.0
# 2007-01-31        29000.0
# 2007-02-28         5000.0
# 2007-03-31        10000.0
# 2007-04-30         1500.0
# 2007-05-31         2500.0
# 2007-06-30        19000.0
# 2007-07-31        16500.0
# 2007-08-31         9200.0
# 2007-09-30        13440.0
# 2007-10-31        30400.0
# 2007-11-30         6500.0
# 2007-12-31         4600.0
# 2008-01-31        10700.0
# 2008-02-28         9700.0
# 2008-03-31        32700.0
# 2008-04-30         3700.0
# 2008-05-31        15500.0
# 2008-06-30         1200.0
# 2008-07-31        17440.0
# 2008-08-31         8400.0
# 2008-09-30        15230.0
# 2008-10-31         6640.0
# 2008-11-30          550.0
# 2008-12-31         9500.0
# 2009-01-31         1700.0
# 2009-02-28         2700.0
# 2009-03-31         1000.0
# 2009-04-30         7000.0
# 2009-05-31         4000.0
# 2009-06-30        18000.0
# 2009-07-31        18000.0
# 2009-08-31        30000.0
# 2009-09-30        24000.0
# 2009-10-31         8000.0
# 2009-11-30        20000.0
# 2009-12-31        18400.0
# 2010-01-31         4400.0
# 2010-02-28         2500.0
# 2010-03-31        14340.0
# 2010-04-30         7600.0
# 2010-05-31        12000.0
# 2010-06-30        11000.0
# 2010-07-31        20000.0
# 2010-08-31        40500.0
# 2010-09-30        20500.0
# 2010-10-31        32000.0
# 2010-11-30         1000.0
# 2010-12-31         1000.0
# 2011-01-31        16000.0
# 2011-02-28         8000.0
# 2011-03-31         6000.0
# 2011-04-30        22000.0
# 2011-05-31         8000.0
# 2011-07-31        10000.0
# 2011-08-31         1200.0
# 2011-09-30        20400.0
# 2011-10-31        10500.0
# 2011-11-30        24340.0
# 2011-12-31        11600.0
# 2012-01-31        10000.0
# 2012-02-28        14000.0
# 2012-03-31        14000.0
# 2012-04-30         9500.0
# 2012-05-31        16500.0
# 2012-06-30        34000.0
# 2012-07-31        17000.0
# 2012-08-31         1000.0
# 2012-09-30        14000.0
# 2012-10-31         4000.0
# 2012-11-30         6000.0
# 2012-12-31         6000.0

# %%
df.plot(kind='line', figsize=(10, 6), rot=22)
# Out:
# <Axes: xlabel='Data'>

# %% [markdown]
# Gráfico das maiores vendas do ano, agrupados por mês.

# %%
result = conn.fetch('''
SELECT
    d.year,
    d.month,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
GROUP BY
    d.year,
    d.month
ORDER BY
    total desc;
''')

# %%
df = pd.DataFrame(result, columns=['Ano', 'Mês', 'Total vendido'])
df['Data'] = df[['Mês', 'Ano']].astype(str).apply(lambda x: '/'.join(x), axis=1)
df.set_index('Data', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#           Ano  Mês  Total vendido
# Data
# 10/2005  2005   10        49200.0
# 8/2010   2010    8        40500.0
# 6/2012   2012    6        34000.0
# 3/2008   2008    3        32700.0
# 10/2010  2010   10        32000.0
# %%
df['Total vendido'].iloc[:20].plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Data'>

# %% [markdown]
# Gráfico das maiores vendas no ano, agrupados por mês e clientes;

# %%
result = conn.fetch('''
SELECT
    d.year,
    d.month,
    c.customer_name,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
INNER JOIN customer_dim c ON
    o.customer_sk = c.customer_sk
GROUP BY
    d.year,
    d.month,
    c.customer_sk
ORDER BY
    total desc;
''')

# %%
df = pd.DataFrame(result, columns=['Ano', 'Mês', 'Cliente', 'Total vendido'])
df['Data'] = df[['Mês', 'Ano', 'Cliente']].astype(str).apply(lambda x: f'{x[0]}/{x[1]} ({x[2]})', axis=1)
df.set_index('Data', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#                                   Ano  Mês                 Cliente  \
# Data
# 10/2007 (Medium Retailers)       2007   10        Medium Retailers
# 1/2007 (Wonderful Shops)         2007    1         Wonderful Shops
# 12/2006 (Medium Retailers)       2006   12        Medium Retailers
# 9/2005 (Good Companies)          2005    9          Good Companies
# 3/2008 (Good Companies)          2008    3          Good Companies
# 7/2007 (Big Customers)           2007    7           Big Customers
# 8/2006 (Iron Mount)              2006    8              Iron Mount
# 10/2010 (Iron Mount)             2010   10              Iron Mount
# 6/2012 (Iron Mount)              2012    6              Iron Mount
# 12/2009 (Iron Mount)             2009   12              Iron Mount
# 10/2005 (Iron Mount)             2005   10              Iron Mount
# 11/2005 (Big Deals)              2005   11               Big Deals
# 6/2007 (Computer Shops)          2007    6          Computer Shops
# 7/2012 (Wonderful Shops)         2012    7         Wonderful Shops
# 10/2005 (Distro Inc)             2005   10              Distro Inc
# 1/2006 (Ticanos Com)             2006    1             Ticanos Com
# 9/2011 (Ticanos Com)             2011    9             Ticanos Com
# 10/2010 (Ticanos Com)            2010   10             Ticanos Com
# 10/2005 (Ticanos Com)            2005   10             Ticanos Com
# 9/2006 (Loyal Clients)           2006    9           Loyal Clients
# 5/2008 (Big Customers)           2008    5           Big Customers
# 10/2006 (Loney Clients)          2006   10           Loney Clients
# 11/2006 (Small Stores)           2006   11            Small Stores
# 9/2007 (Small Stores)            2007    9            Small Stores
# 7/2008 (Small Stores)            2008    7            Small Stores
# 5/2005 (Wonderful Shops)         2005    5         Wonderful Shops
# 6/2009 (Good Companies)          2009    6          Good Companies
# 7/2009 (Wonderful Shops)         2009    7         Wonderful Shops
# 8/2009 (Big Customers)           2009    8           Big Customers
# 7/2006 (Mex Free)                2006    7                Mex Free
# 9/2010 (Mex Free)                2010    9                Mex Free
# 5/2012 (Mex Free)                2012    5                Mex Free
# 11/2009 (Good Companies)         2009   11          Good Companies
# 7/2006 (Good Companies)          2006    7          Good Companies
# 9/2005 (Best Companies)          2005    9          Best Companies
# 6/2012 (Medium Retailers)        2012    6        Medium Retailers
# 9/2012 (Great Deals)             2012    9             Great Deals
# 7/2006 (Good Products)           2006    7           Good Products
# 8/2011 (Loyal Clients)                  1200.0
# 2/2005 (Small Stores)                   1000.0
# 3/2009 (Big Customers)                  1000.0
# 4/2009 (Small Stores)                   1000.0
# 12/2010 (Small Stores)                  1000.0
# 7/2012 (Big Customers)                  1000.0
# 8/2012 (Small Stores)                   1000.0
# 2/2010 (Small Stores)                   1000.0
# 10/2006 (Small Stores)                  1000.0
# 12/2005 (Big Deals)                     1000.0
# 9/2006 (Small Country)                  1000.0
# 1/2006 (Good Clients)                   1000.0
# 1/2007 (Good Clients)                   1000.0
# 1/2005 (Loyal Clients)                  1000.0
# 2/2005 (Develop IN)                     1000.0
# 1/2005 (Distinguished Partners)         1000.0
# 10/2006 (Loyal Clients)                 1000.0
# 3/2006 (Good Clients)                   1000.0
# 1/2007 (Loyal Clients)                  1000.0
# 4/2012 (Develop IN)                     1000.0
# 2/2012 (Life Connect)                   1000.0
# 11/2010 (Loyal Clients)                 1000.0
# 10/2011 (Life Connect)                  1000.0
# 4/2006 (Loyal Clients)                  1000.0
# 2/2007 (Life Connect)                   1000.0
# 10/2008 (Good Companies)                 640.0
# 11/2008 (Loyal Clients)                  550.0
# 8/2008 (Medium Retailers)                400.0

# %%
df['Total vendido'].iloc[:20].plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Data'>

# %% [markdown]
# Gráfico anual de vendas, contendo os produtos, valores dos pedidos,
# agregados pelo ano, produto e cidade do cliente.

# %%
result = conn.fetch('''
SELECT
    d.year,
    p.product_name,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
INNER JOIN product_dim p ON
    o.product_sk = p.product_sk
GROUP BY
    d.year,
    p.product_sk
ORDER BY
    total desc;
''')

# %%
df = pd.DataFrame(result, columns=['Ano', 'Produto', 'Total vendido'])
df['Produto (Ano)'] = df[['Produto', 'Ano']].astype(str).apply(lambda x: f'{x[0]} ({x[1]})', axis=1)
df.set_index('Produto (Ano)', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#                         Ano         Produto  Total vendido
# Produto (Ano)
# Pen Drive (2005)       2005       Pen Drive        55200.0
# Pen Drive (2011)       2011       Pen Drive        48800.0
# Mouse (2005)           2005           Mouse        46400.0
# Pen Drive (2006)       2006       Pen Drive        45200.0
# Pen Drive (2009)       2009       Pen Drive        41200.0
# Keyboard (2006)        2006        Keyboard        40280.0
# Batery (2007)          2007          Batery        40100.0
# Pocket Storage (2005)  2005  Pocket Storage        35000.0
# Keyboard (2010)        2010        Keyboard        34500.0
# Mouse (2009)           2009           Mouse        34000.0
# Mouse (2008)           2008           Mouse        32850.0
# Pen Drive (2010)       2010       Pen Drive        32600.0
# Mouse (2012)           2012           Mouse        32000.0
# Batery (2006)          2006          Batery        30000.0
# Pen Drive (2007)       2007       Pen Drive        27400.0
# LCD Panel (2006)       2006       LCD Panel        25200.0
# Ink Print (2011)       2011       Ink Print        24000.0
# Ink Print (2012)       2012       Ink Print        24000.0
# Pen Drive (2012)       2012       Pen Drive        24000.0
# Pocket Storage (2010)  2010  Pocket Storage        22000.0
# External Cam (2007)    2007    External Cam        21000.0
# Mouse (2011)           2011           Mouse        20400.0
# Pen Drive (2008)       2008       Pen Drive        20000.0
# Pocket Storage (2006)  2006  Pocket Storage        20000.0
# Batery (2012)          2012          Batery        19500.0
# LCD Panel (2010)       2010       LCD Panel        18500.0
# Keyboard (2009)        2009        Keyboard        18000.0
# LCD Panel (2012)       2012       LCD Panel        17000.0
# Backup Storage (2010)  2010  Backup Storage        17000.0
# Microphone (2012)      2012      Microphone        16500.0
# Microphone (2006)      2006      Microphone        16000.0
# Ink Print (2007)       2007       Ink Print        16000.0
# Head Phone (2009)      2009      Head Phone        16000.0
# Keyboard (2007)        2007        Keyboard        15940.0
# Batery (2008)          2008          Batery        15500.0
# Batery (2010)          2010          Batery        14500.0
# Pocket Storage (2009)  2009  Pocket Storage        14200.0
# Keyboard (2008)        2008        Keyboard        13440.0
# WebCam (2007)          2007          WebCam        11500.0
# Keyboard (2012)        2012        Keyboard        11000.0
# Ink Print (2006)       2006       Ink Print        11000.0
# LCD Panel (2011)       2011       LCD Panel        10500.0
# WebCam (2009)          2009          WebCam        10400.0
# Keyboard (2011)        2011        Keyboard        10340.0
# Mouse (2006)           2006           Mouse        10000.0
# Head Phone (2008)      2008      Head Phone        10000.0
# Mouse (2010)           2010           Mouse        10000.0
# External Cam (2010)    2010    External Cam         9340.0
# LCD Panel (2008)       2008       LCD Panel         9200.0
# LCD Panel (2005)       2005       LCD Panel         9000.0
# LCD Panel (2009)       2009       LCD Panel         8000.0
# Microphone (2011)      2011      Microphone         8000.0
# Backup Storage (2008)  2008  Backup Storage         8000.0
# Backup Storage (2011)  2011  Backup Storage         8000.0
# Pocket Storage (2007)  2007  Pocket Storage         8000.0
# WebCam (2008)          2008          WebCam         6400.0
# External Cam (2005)    2005    External Cam         6000.0
# External Cam (2008)    2008    External Cam         6000.0
# Keyboard (2005)        2005        Keyboard         6000.0
# External Cam (2006)    2006    External Cam         6000.0
# Ink Print (2009)       2009       Ink Print         6000.0
# Head Phone (2010)      2010      Head Phone         4400.0
# LCD Panel (2007)       2007       LCD Panel         4200.0
# Batery (2011)          2011          Batery         4000.0
# Microphone (2008)      2008      Microphone         4000.0
# Batery (2005)          2005          Batery         4000.0
# Microphone (2010)      2010      Microphone         4000.0
# Head Phone (2006)      2006      Head Phone         4000.0
# Batery (2009)          2009          Batery         4000.0
# WebCam (2011)          2011          WebCam         4000.0
# Pocket Storage (2008)  2008  Pocket Storage         4000.0
# Mouse (2007)           2007           Mouse         3500.0
# Ink Print (2005)       2005       Ink Print         2500.0
# Pocket Storage (2012)  2012  Pocket Storage         2000.0
# Filter (2008)          2008          Filter         1230.0
# Backup Storage (2005)  2005  Backup Storage         1000.0
# Backup Storage (2009)  2009  Backup Storage         1000.0
# Hard Disk (2008)       2008       Hard Disk          640.0

# %%
df['Total vendido'].iloc[:20].plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Produto (Ano)'>

# %%
result = conn.fetch('''
SELECT
    d.year,
    c.customer_city,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
INNER JOIN customer_dim c ON
    o.customer_sk = c.customer_sk
GROUP BY
    d.year,
    c.customer_city
ORDER BY
    total desc;
''')

# %%
df = pd.DataFrame(result, columns=['Ano', 'Cidade', 'Total vendido'])
df['Cidade (Ano)'] = df[['Cidade', 'Ano']].astype(str).apply(lambda x: f'{x[0]} ({x[1]})', axis=1)
df.set_index('Cidade (Ano)', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#                        Ano         Cidade  Total vendido
# Cidade (Ano)
# Pittsburgh (2006)     2006     Pittsburgh       106240.0
# Mechanicsburg (2005)  2005  Mechanicsburg        79000.0
# Pittsburgh (2010)     2010     Pittsburgh        71400.0
# Mechanicsburg (2007)  2007  Mechanicsburg        70800.0
# Mechanicsburg (2009)  2009  Mechanicsburg        59000.0
# Mechanicsburg (2008)  2008  Mechanicsburg        58570.0
# Pittsburgh (2012)     2012     Pittsburgh        53500.0
# Pittsburgh (2007)     2007     Pittsburgh        53340.0
# Pittsburgh (2008)     2008     Pittsburgh        52290.0
# Pittsburgh (2005)     2005     Pittsburgh        45100.0
# Pittsburgh (2011)     2011     Pittsburgh        43100.0
# Mechanicsburg (2011)  2011  Mechanicsburg        43000.0
# San Francisco (2009)  2009  San Francisco        38000.0
# Mechanicsburg (2012)  2012  Mechanicsburg        38000.0
# Pittsburgh (2009)     2009     Pittsburgh        35400.0
# San Diego (2010)      2010      San Diego        33940.0
# San Diego (2006)      2006      San Diego        33940.0
# San Francisco (2006)  2006  San Francisco        24000.0
# San Diego (2012)      2012      San Diego        22000.0
# San Francisco (2011)  2011  San Francisco        20000.0
# San Diego (2009)      2009      San Diego        18700.0
# Mechaniscburg (2011)  2011  Mechaniscburg        16000.0
# Mechaniscburg (2006)  2006  Mechaniscburg        16000.0
# Mechaniscburg (2010)  2010  Mechaniscburg        16000.0
# Mechaniscburg (2005)  2005  Mechaniscburg        16000.0
# Mechanicsburg (2006)  2006  Mechanicsburg        16000.0
# San Diego (2005)      2005      San Diego        16000.0
# Texas (2010)          2010          Texas        15500.0
# Texas (2006)          2006          Texas        15500.0
# Texas (2012)          2012          Texas        15500.0
# Los Angeles (2007)    2007    Los Angeles        14000.0
# Mechanicsburg (2010)  2010  Mechanicsburg        12000.0
# San Diego (2011)      2011      San Diego        11940.0
# Los Angeles (2012)    2012    Los Angeles        11000.0
# San Francisco (2010)  2010  San Francisco        10000.0
# Mechaniscburg (2008)  2008  Mechaniscburg        10000.0
# California (2010)     2010     California         8000.0
# San Francisco (2005)  2005  San Francisco         8000.0
# Texas (2008)          2008          Texas         6700.0
# Mechaniscburg (2012)  2012  Mechaniscburg         6000.0
# San Francisco (2007)  2007  San Francisco         4000.0
# Los Angeles (2011)    2011    Los Angeles         4000.0
# San Diego (2008)      2008      San Diego         3700.0
# San Diego (2007)      2007      San Diego         3000.0
# Texas (2007)          2007          Texas         2500.0
# Texas (2009)          2009          Texas         1700.0
# Los Angeles (2005)    2005    Los Angeles         1000.0

# %%
df['Total vendido'].iloc[:20].plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Cidade (Ano)'>

# %% [markdown]
# Gráfico anual de vendas, contendo as quantidades dos pedidos,
# agregados por ano.

# %%
result = conn.fetch('''
SELECT
    d.year,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
GROUP BY
    d.year
ORDER BY
    total desc;
''')

# %%
df = pd.DataFrame(result, columns=['Ano', 'Total vendido'])
df.set_index('Ano', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#       Total vendido
# Ano
# 2006       211680.0
# 2010       166840.0
# 2005       165100.0
# 2009       152800.0
# 2007       147640.0
# 2012       146000.0
# 2011       138040.0
# 2008       131260.0
# 2013        60700.0

# %%
df['Total vendido'].plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Ano'>

# %% [markdown]
# Gráfico do resumo das vendas mensais e o número de encomendas a
# cada mês, cuja categoria seja PERIPHERAL.

# %%
result = conn.fetch('''
SELECT
    d.year,
    d.month,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
INNER JOIN product_dim p ON
    o.product_sk = p.product_sk
WHERE p.product_category = 'PERIPHERAL'
GROUP BY
    d.year,
    d.month
ORDER BY
    year asc, month asc;
''')

# %%
df = pd.DataFrame(result, columns=['Ano', 'Mês', 'Total vendido'])
df['Data'] = df[['Mês', 'Ano']].astype(str).apply(lambda x: '/'.join(x), axis=1)
df.set_index('Data', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#           Ano  Mês  Total vendido
# Data
# 3/2005   2005    3         4000.0
# 5/2005   2005    5        12000.0
# 6/2005   2005    6         6000.0
# 9/2005   2005    9        30000.0
# 11/2005  2005   11         4400.0
# 12/2005  2005   12         2500.0
# 1/2006   2006    1        20340.0
# 3/2006   2006    3         6000.0
# 4/2006   2006    4        11000.0
# 6/2006   2006    6         8500.0
# 7/2006   2006    7        30500.0
# 9/2006   2006    9        16500.0
# 11/2006  2006   11        18440.0
# 2/2007   2007    2         4000.0
# 3/2007   2007    3         2000.0
# 4/2007   2007    4         1500.0
# 6/2007   2007    6        16000.0
# 7/2007   2007    7        15500.0
# 8/2007   2007    8         8000.0
# 9/2007   2007    9        13440.0
# 10/2007  2007   10         4000.0
# 11/2007  2007   11         6500.0
# 12/2007  2007   12         4600.0
# 1/2008   2008    1         2700.0
# 2/2008   2008    2         1700.0
# 3/2008   2008    3        30000.0
# 5/2008   2008    5        15500.0
# 7/2008   2008    7        13440.0
# 8/2008   2008    8          400.0
# 9/2008   2008    9        10000.0
# 11/2008  2008   11          550.0
# 12/2008  2008   12         1500.0
# 4/2009   2009    4         6000.0
# 5/2009   2009    5         4000.0
# 6/2009   2009    6         6000.0
# 7/2009   2009    7        12000.0
# 8/2009   2009    8        30000.0
# 11/2009  2009   11        20000.0
# 1/2010   2010    1         4400.0
# 3/2010   2010    3        10000.0
# 5/2010   2010    5        12000.0
# 6/2010   2010    6         6000.0
# 7/2010   2010    7         6000.0
# 8/2010   2010    8         8500.0
# 9/2010   2010    9        20500.0
# 1/2011   2011    1        12000.0
# 3/2011   2011    3         6000.0
# 4/2011   2011    4         6000.0
# 5/2011   2011    5         8000.0
# 7/2011   2011    7        10000.0
# 9/2011   2011    9         4400.0
# 11/2011  2011   11        16340.0
# 12/2011  2011   12         4000.0
# 1/2012   2012    1         6000.0
# 2/2012   2012    2         6000.0
# 3/2012   2012    3        14000.0
# 4/2012   2012    4         8500.0
# 5/2012   2012    5        16500.0
# 6/2012   2012    6        10000.0
# 7/2012   2012    7        16000.0
# 9/2012   2012    9        14000.0
# 11/2012  2012   11         6000.0
# 12/2012  2012   12         6000.0
# 2/2013   2013    2        16700.0

# %%
df['Total vendido'].plot(kind='line', figsize=(10, 6), rot=30)
# Out:
# <Axes: xlabel='Data'>

# %% [markdown]
# Gráfico das ordens de venda de produtos com valores mensais maiores
# que 35 mil.

# %%
result = conn.fetch('''
SELECT
    d.year,
    d.month,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN date_dim d ON
    o.order_date_sk = d.date_sk
GROUP BY
    d.year,
    d.month
HAVING total > 35000
ORDER BY
    year asc, month asc;
''')

# %%
df = pd.DataFrame(result, columns=['Ano', 'Mês', 'Total vendido'])
df['Data'] = df[['Mês', 'Ano']].astype(str).apply(lambda x: '/'.join(x), axis=1)
df.set_index('Data', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#           Ano  Mês  Total vendido
# Data
# 10/2005  2005   10        49200.0
# 8/2010   2010    8        40500.0
# 2/2013   2013    2        60700.0

# %%
df['Total vendido'].iloc[:20].plot(kind='bar', figsize=(10, 6), rot=30)
# Out:
# <Axes: xlabel='Data'>

# %% [markdown]
# Gráfico das cidades que mais gastaram nos últimos anos.

# %%
result = conn.fetch('''
SELECT
    c.customer_city,
    SUM(o.order_amount) AS total
FROM
    sales_order_fact o
INNER JOIN customer_dim c ON
    o.customer_sk = c.customer_sk
GROUP BY
    c.customer_city
ORDER BY
    total desc;
''')

# %%
df = pd.DataFrame(result, columns=['Cidade', 'Total vendido'])
df.set_index('Cidade', inplace=True)
df['Total vendido'] = df['Total vendido'].astype(float)
df
# Out:
#                Total vendido
# Cidade
# Pittsburgh          503670.0
# Mechanicsburg       390870.0
# San Diego           146120.0
# San Francisco       104000.0
# Mechaniscburg        80000.0
# Texas                57400.0
# Los Angeles          30000.0
# California            8000.0

# %%
df['Total vendido'].plot(kind='bar', figsize=(10, 6), rot=90)
# Out:
# <Axes: xlabel='Cidade'>
